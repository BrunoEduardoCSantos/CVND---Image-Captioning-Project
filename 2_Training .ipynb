# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**  To select the embed and hidden size (=512)  I used [this paper](https://arxiv.org/pdf/1411.4555.pdf). Regarding the batch size was a based on suggestion of Udacity materials for ideal choice to start with. Regarding the CNN architecture, I kept the resnet and add batch normalization to improve training performance as well as better learning parameters. For the Decoder architecture I used LSTM  based on  [this paper](https://arxiv.org/pdf/1411.4555.pdf) together with dropout layer to avoid overfitting prone training. In LSTM architecture I use one layer based on previous mentioned paper, but a larger hidden size to provide it with a "larger memory". For next steps, we could try moving on to an extra layer to check the benifits.
# Finally, for vocabulary threshold I used the previous mentioned paper as a reference together with a frequency plot in notebook 1 to find the most common caption size.
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**  The transform_train was left unchanged since it provides the right image size to feed into Resnet as well as some data augmentation techniques such as flip. In addition, the image is normalized to have allow the network to learn faster.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** To select the embed and hidden size (=512)  I used [this paper](https://arxiv.org/pdf/1411.4555.pdf). Regarding the batch size (=32) was a based on suggestion of Udacity materials for ideal choice to start with. In LSTM architecture I use one layer based on previous mentioned paper, but a larger hidden size to provide it with a "larger memory".The weight initialization was select assuming a gaussian error distribution as well a input normalized data. For selecting the learning rate I used 0.001 since allow us not to step out of the minimum of loss function.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** In practice Adam is currently recommended as the default algorithm to use, and often works slightly better than RMSProp. However, it is often also worth trying SGD+Nesterov Momentum as an alternative. The full Adam update also includes a bias correction mechanism, which compensates for the fact that in the first few time steps the vectors m,v are both initialized and therefore biased at zero, before they fully “warm up” (based on [this](http://cs231n.github.io/neural-networks-3/#ada) reference)

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
import nltk
nltk.download('punkt')


#1: Select appropriate values for the Python variables below.
batch_size =   32    # batch size
vocab_threshold = 6      # minimum word count threshold
vocab_from_file = False    # if True, load existing vocab file
embed_size = 512          # dimensionality of image and word embeddings
hidden_size = 512        # number of features in hidden state of the RNN decoder
num_epochs = 3 # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

#2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

#3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters()) + list(encoder.batch.parameters())

# Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# loading annotations into memory...
# Done (t=0.89s)
# creating index...
# index created!
# [0/414113] Tokenizing captions...
# [100000/414113] Tokenizing captions...
# [200000/414113] Tokenizing captions...
# [300000/414113] Tokenizing captions...
# [400000/414113] Tokenizing captions...
# loading annotations into memory...
# Done (t=0.94s)
# creating index...
#   0%|          | 633/414113 [00:00<01:05, 6326.87it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:08<00:00, 6055.23it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 4.0930, Perplexity: 59.9217
# Epoch [1/3], Step [200/12942], Loss: 3.6826, Perplexity: 39.74835
# Epoch [1/3], Step [300/12942], Loss: 3.4532, Perplexity: 31.6012
# Epoch [1/3], Step [400/12942], Loss: 2.9946, Perplexity: 19.97675
# Epoch [1/3], Step [500/12942], Loss: 3.3046, Perplexity: 27.2377
# Epoch [1/3], Step [600/12942], Loss: 3.1851, Perplexity: 24.1689
# Epoch [1/3], Step [700/12942], Loss: 3.1563, Perplexity: 23.4826
# Epoch [1/3], Step [800/12942], Loss: 2.9776, Perplexity: 19.6404
# Epoch [1/3], Step [900/12942], Loss: 3.2925, Perplexity: 26.9093
# Epoch [1/3], Step [1000/12942], Loss: 2.5073, Perplexity: 12.2715
# Epoch [1/3], Step [1100/12942], Loss: 2.5374, Perplexity: 12.6465
# Epoch [1/3], Step [1200/12942], Loss: 2.6817, Perplexity: 14.6098
# Epoch [1/3], Step [1300/12942], Loss: 3.3136, Perplexity: 27.4834
# Epoch [1/3], Step [1400/12942], Loss: 2.9322, Perplexity: 18.7693
# Epoch [1/3], Step [1500/12942], Loss: 2.7005, Perplexity: 14.8871
# Epoch [1/3], Step [1600/12942], Loss: 2.3631, Perplexity: 10.6235
# Epoch [1/3], Step [1700/12942], Loss: 2.3865, Perplexity: 10.8753
# Epoch [1/3], Step [1800/12942], Loss: 2.5250, Perplexity: 12.4914
# Epoch [1/3], Step [1900/12942], Loss: 2.4378, Perplexity: 11.4475
# Epoch [1/3], Step [2000/12942], Loss: 2.3577, Perplexity: 10.5665
# Epoch [1/3], Step [2100/12942], Loss: 2.7986, Perplexity: 16.4222
# Epoch [1/3], Step [2200/12942], Loss: 2.3110, Perplexity: 10.0841
# Epoch [1/3], Step [2300/12942], Loss: 2.2685, Perplexity: 9.66477
# Epoch [1/3], Step [2400/12942], Loss: 2.7283, Perplexity: 15.3075
# Epoch [1/3], Step [2500/12942], Loss: 2.4023, Perplexity: 11.0485
# Epoch [1/3], Step [2600/12942], Loss: 2.2429, Perplexity: 9.42076
# Epoch [1/3], Step [2700/12942], Loss: 2.4782, Perplexity: 11.9197
# Epoch [1/3], Step [2800/12942], Loss: 2.1781, Perplexity: 8.82911
# Epoch [1/3], Step [2900/12942], Loss: 2.9944, Perplexity: 19.9735
# Epoch [1/3], Step [3000/12942], Loss: 2.2769, Perplexity: 9.74621
# Epoch [1/3], Step [3100/12942], Loss: 2.1964, Perplexity: 8.99248
# Epoch [1/3], Step [3200/12942], Loss: 2.2360, Perplexity: 9.35605
# Epoch [1/3], Step [3300/12942], Loss: 2.4477, Perplexity: 11.5622
# Epoch [1/3], Step [3400/12942], Loss: 2.4757, Perplexity: 11.8900
# Epoch [1/3], Step [3500/12942], Loss: 2.1258, Perplexity: 8.37934
# Epoch [1/3], Step [3600/12942], Loss: 2.2189, Perplexity: 9.19683
# Epoch [1/3], Step [3700/12942], Loss: 1.9381, Perplexity: 6.94521
# Epoch [1/3], Step [3800/12942], Loss: 2.2430, Perplexity: 9.42153
# Epoch [1/3], Step [3900/12942], Loss: 2.7043, Perplexity: 14.9437
# Epoch [1/3], Step [4000/12942], Loss: 2.5001, Perplexity: 12.1839
# Epoch [1/3], Step [4100/12942], Loss: 3.1267, Perplexity: 22.7983
# Epoch [1/3], Step [4200/12942], Loss: 2.1532, Perplexity: 8.61266
# Epoch [1/3], Step [4300/12942], Loss: 2.8299, Perplexity: 16.9436
# Epoch [1/3], Step [4400/12942], Loss: 2.1320, Perplexity: 8.43137
# Epoch [1/3], Step [4500/12942], Loss: 2.0937, Perplexity: 8.11504
# Epoch [1/3], Step [4600/12942], Loss: 2.3146, Perplexity: 10.1206
# Epoch [1/3], Step [4700/12942], Loss: 2.4367, Perplexity: 11.4356
# Epoch [1/3], Step [4800/12942], Loss: 2.3497, Perplexity: 10.4827
# Epoch [1/3], Step [4900/12942], Loss: 2.2653, Perplexity: 9.634085
# Epoch [1/3], Step [5000/12942], Loss: 2.0349, Perplexity: 7.65176
# Epoch [1/3], Step [5100/12942], Loss: 2.5795, Perplexity: 13.1903
# Epoch [1/3], Step [5200/12942], Loss: 2.0856, Perplexity: 8.04963
# Epoch [1/3], Step [5300/12942], Loss: 2.7532, Perplexity: 15.6927
# Epoch [1/3], Step [5400/12942], Loss: 2.3276, Perplexity: 10.2533
# Epoch [1/3], Step [5500/12942], Loss: 2.5808, Perplexity: 13.2071
# Epoch [1/3], Step [5600/12942], Loss: 2.1138, Perplexity: 8.27986
# Epoch [1/3], Step [5700/12942], Loss: 2.2325, Perplexity: 9.32306
# Epoch [1/3], Step [5800/12942], Loss: 2.1775, Perplexity: 8.82407
# Epoch [1/3], Step [5900/12942], Loss: 2.1234, Perplexity: 8.35944
# Epoch [1/3], Step [6000/12942], Loss: 2.3570, Perplexity: 10.5588
# Epoch [1/3], Step [6100/12942], Loss: 2.4057, Perplexity: 11.0860
# Epoch [1/3], Step [6200/12942], Loss: 2.2161, Perplexity: 9.17152
# Epoch [1/3], Step [6300/12942], Loss: 2.4194, Perplexity: 11.2387
# Epoch [1/3], Step [6400/12942], Loss: 2.5399, Perplexity: 12.6790
# Epoch [1/3], Step [6500/12942], Loss: 2.4232, Perplexity: 11.2824
# Epoch [1/3], Step [6600/12942], Loss: 2.1004, Perplexity: 8.169837
# Epoch [1/3], Step [6700/12942], Loss: 2.2397, Perplexity: 9.39079
# Epoch [1/3], Step [6800/12942], Loss: 2.3148, Perplexity: 10.1228
# Epoch [1/3], Step [6900/12942], Loss: 2.3477, Perplexity: 10.4617
# Epoch [1/3], Step [7000/12942], Loss: 2.0080, Perplexity: 7.44821
# Epoch [1/3], Step [7100/12942], Loss: 3.5210, Perplexity: 33.8187
# Epoch [1/3], Step [7200/12942], Loss: 2.3085, Perplexity: 10.0595
# Epoch [1/3], Step [7300/12942], Loss: 1.9582, Perplexity: 7.08640
# Epoch [1/3], Step [7400/12942], Loss: 2.2614, Perplexity: 9.59614
# Epoch [1/3], Step [7500/12942], Loss: 2.1079, Perplexity: 8.23091
# Epoch [1/3], Step [7600/12942], Loss: 2.3637, Perplexity: 10.6298
# Epoch [1/3], Step [7700/12942], Loss: 1.8581, Perplexity: 6.41165
# Epoch [1/3], Step [7800/12942], Loss: 2.2045, Perplexity: 9.06602
# Epoch [1/3], Step [7900/12942], Loss: 2.2542, Perplexity: 9.52816
# Epoch [1/3], Step [8000/12942], Loss: 2.3341, Perplexity: 10.3205
# Epoch [1/3], Step [8100/12942], Loss: 1.9934, Perplexity: 7.34035
# Epoch [1/3], Step [8200/12942], Loss: 2.0681, Perplexity: 7.91004
# Epoch [1/3], Step [8300/12942], Loss: 2.1537, Perplexity: 8.61711
# Epoch [1/3], Step [8400/12942], Loss: 2.2082, Perplexity: 9.09901
# Epoch [1/3], Step [8500/12942], Loss: 1.9739, Perplexity: 7.19883
# Epoch [1/3], Step [8600/12942], Loss: 2.1496, Perplexity: 8.58156
# Epoch [1/3], Step [8700/12942], Loss: 1.8726, Perplexity: 6.50497
# Epoch [1/3], Step [8800/12942], Loss: 2.6594, Perplexity: 14.2876
# Epoch [1/3], Step [8900/12942], Loss: 2.1996, Perplexity: 9.02144
# Epoch [1/3], Step [9000/12942], Loss: 2.3002, Perplexity: 9.97584
# Epoch [1/3], Step [9100/12942], Loss: 2.1629, Perplexity: 8.69677
# Epoch [1/3], Step [9200/12942], Loss: 2.1452, Perplexity: 8.54417
# Epoch [1/3], Step [9300/12942], Loss: 2.2415, Perplexity: 9.40791
# Epoch [1/3], Step [9400/12942], Loss: 2.1305, Perplexity: 8.41890
# Epoch [1/3], Step [9500/12942], Loss: 2.0564, Perplexity: 7.81795
# Epoch [1/3], Step [9600/12942], Loss: 2.2667, Perplexity: 9.64770
# Epoch [1/3], Step [9700/12942], Loss: 2.0413, Perplexity: 7.70033
# Epoch [1/3], Step [9800/12942], Loss: 1.8886, Perplexity: 6.61013
# Epoch [1/3], Step [9900/12942], Loss: 2.1343, Perplexity: 8.45139
# Epoch [1/3], Step [10000/12942], Loss: 2.3754, Perplexity: 10.7554
# Epoch [1/3], Step [10100/12942], Loss: 2.2118, Perplexity: 9.13184
# Epoch [1/3], Step [10200/12942], Loss: 2.1755, Perplexity: 8.80625
# Epoch [1/3], Step [10300/12942], Loss: 2.0135, Perplexity: 7.48970
# Epoch [1/3], Step [10400/12942], Loss: 2.4569, Perplexity: 11.6691
# Epoch [1/3], Step [10500/12942], Loss: 2.1269, Perplexity: 8.38877
# Epoch [1/3], Step [10600/12942], Loss: 1.9762, Perplexity: 7.21544
# Epoch [1/3], Step [10700/12942], Loss: 2.0423, Perplexity: 7.70830
# Epoch [1/3], Step [10800/12942], Loss: 2.0667, Perplexity: 7.89886
# Epoch [1/3], Step [10900/12942], Loss: 2.0808, Perplexity: 8.01118
# Epoch [1/3], Step [11000/12942], Loss: 2.4213, Perplexity: 11.2603
# Epoch [1/3], Step [11100/12942], Loss: 2.1847, Perplexity: 8.88813
# Epoch [1/3], Step [11200/12942], Loss: 2.1844, Perplexity: 8.88558
# Epoch [1/3], Step [11300/12942], Loss: 2.6171, Perplexity: 13.6960
# Epoch [1/3], Step [11400/12942], Loss: 2.1419, Perplexity: 8.51523
# Epoch [1/3], Step [11500/12942], Loss: 1.9230, Perplexity: 6.84155
# Epoch [1/3], Step [11600/12942], Loss: 2.2255, Perplexity: 9.25823
# Epoch [1/3], Step [11700/12942], Loss: 1.8409, Perplexity: 6.30210
# Epoch [1/3], Step [11800/12942], Loss: 1.9322, Perplexity: 6.90508
# Epoch [1/3], Step [11900/12942], Loss: 1.9539, Perplexity: 7.05622
# Epoch [1/3], Step [12000/12942], Loss: 1.8986, Perplexity: 6.67676
# Epoch [1/3], Step [12100/12942], Loss: 2.1564, Perplexity: 8.63984
# Epoch [1/3], Step [12200/12942], Loss: 2.1798, Perplexity: 8.84480
# Epoch [1/3], Step [12300/12942], Loss: 2.2863, Perplexity: 9.83892
# Epoch [1/3], Step [12400/12942], Loss: 2.2922, Perplexity: 9.89630
# Epoch [1/3], Step [12500/12942], Loss: 2.3379, Perplexity: 10.3592
# Epoch [1/3], Step [12600/12942], Loss: 2.1404, Perplexity: 8.50283
# Epoch [1/3], Step [12700/12942], Loss: 1.9643, Perplexity: 7.13007
# Epoch [1/3], Step [12800/12942], Loss: 2.4969, Perplexity: 12.1447
# Epoch [1/3], Step [12900/12942], Loss: 2.1053, Perplexity: 8.20929
# Epoch [2/3], Step [100/12942], Loss: 1.9310, Perplexity: 6.8962511
# Epoch [2/3], Step [200/12942], Loss: 2.1114, Perplexity: 8.25969
# Epoch [2/3], Step [300/12942], Loss: 1.7633, Perplexity: 5.83174
# Epoch [2/3], Step [400/12942], Loss: 2.0449, Perplexity: 7.72848
# Epoch [2/3], Step [500/12942], Loss: 1.8948, Perplexity: 6.65090
# Epoch [2/3], Step [600/12942], Loss: 2.4253, Perplexity: 11.3052
# Epoch [2/3], Step [700/12942], Loss: 2.5254, Perplexity: 12.4965
# Epoch [2/3], Step [800/12942], Loss: 2.3611, Perplexity: 10.6023
# Epoch [2/3], Step [900/12942], Loss: 2.1618, Perplexity: 8.68668
# Epoch [2/3], Step [1000/12942], Loss: 2.1120, Perplexity: 8.2645
# Epoch [2/3], Step [1100/12942], Loss: 2.0738, Perplexity: 7.95535
# Epoch [2/3], Step [1200/12942], Loss: 2.0319, Perplexity: 7.62841
# Epoch [2/3], Step [1300/12942], Loss: 2.1872, Perplexity: 8.91034
# Epoch [2/3], Step [1400/12942], Loss: 1.8644, Perplexity: 6.45223
# Epoch [2/3], Step [1500/12942], Loss: 3.1988, Perplexity: 24.5023
# Epoch [2/3], Step [1600/12942], Loss: 2.1989, Perplexity: 9.01476
# Epoch [2/3], Step [1700/12942], Loss: 2.0387, Perplexity: 7.68083
# Epoch [2/3], Step [1800/12942], Loss: 2.0035, Perplexity: 7.41533
# Epoch [2/3], Step [1900/12942], Loss: 2.3015, Perplexity: 9.98963
# Epoch [2/3], Step [2000/12942], Loss: 2.0235, Perplexity: 7.56498
# Epoch [2/3], Step [2100/12942], Loss: 1.9784, Perplexity: 7.23101
# Epoch [2/3], Step [2200/12942], Loss: 1.9618, Perplexity: 7.11245
# Epoch [2/3], Step [2300/12942], Loss: 1.9913, Perplexity: 7.32470
# Epoch [2/3], Step [2400/12942], Loss: 1.9601, Perplexity: 7.10047
# Epoch [2/3], Step [2500/12942], Loss: 2.2832, Perplexity: 9.80757
# Epoch [2/3], Step [2600/12942], Loss: 2.0945, Perplexity: 8.12181
# Epoch [2/3], Step [2700/12942], Loss: 2.5686, Perplexity: 13.0477
# Epoch [2/3], Step [2800/12942], Loss: 2.0398, Perplexity: 7.68947
# Epoch [2/3], Step [2900/12942], Loss: 1.6175, Perplexity: 5.04072
# Epoch [2/3], Step [3000/12942], Loss: 1.7858, Perplexity: 5.96446
# Epoch [2/3], Step [3100/12942], Loss: 1.9947, Perplexity: 7.35022
# Epoch [2/3], Step [3200/12942], Loss: 2.0238, Perplexity: 7.56728
# Epoch [2/3], Step [3300/12942], Loss: 2.0378, Perplexity: 7.67381
# Epoch [2/3], Step [3400/12942], Loss: 2.1113, Perplexity: 8.25914
# Epoch [2/3], Step [3500/12942], Loss: 1.9493, Perplexity: 7.02367
# Epoch [2/3], Step [3600/12942], Loss: 1.7273, Perplexity: 5.62556
# Epoch [2/3], Step [3700/12942], Loss: 2.0016, Perplexity: 7.40093
# Epoch [2/3], Step [3800/12942], Loss: 1.9231, Perplexity: 6.84228
# Epoch [2/3], Step [3900/12942], Loss: 2.1105, Perplexity: 8.25246
# Epoch [2/3], Step [4000/12942], Loss: 1.6817, Perplexity: 5.37451
# Epoch [2/3], Step [4100/12942], Loss: 2.1511, Perplexity: 8.59414
# Epoch [2/3], Step [4200/12942], Loss: 2.0982, Perplexity: 8.15178
# Epoch [2/3], Step [4300/12942], Loss: 1.7731, Perplexity: 5.88899
# Epoch [2/3], Step [4400/12942], Loss: 2.0330, Perplexity: 7.63703
# Epoch [2/3], Step [4500/12942], Loss: 1.9495, Perplexity: 7.02524
# Epoch [2/3], Step [4600/12942], Loss: 1.8278, Perplexity: 6.21995
# Epoch [2/3], Step [4700/12942], Loss: 2.0131, Perplexity: 7.48637
# Epoch [2/3], Step [4800/12942], Loss: 2.3807, Perplexity: 10.8125
# Epoch [2/3], Step [4900/12942], Loss: 1.9219, Perplexity: 6.83417
# Epoch [2/3], Step [5000/12942], Loss: 2.0644, Perplexity: 7.88078
# Epoch [2/3], Step [5100/12942], Loss: 2.0931, Perplexity: 8.11043
# Epoch [2/3], Step [5200/12942], Loss: 1.9589, Perplexity: 7.09166
# Epoch [2/3], Step [5300/12942], Loss: 2.4491, Perplexity: 11.5781
# Epoch [2/3], Step [5400/12942], Loss: 1.7174, Perplexity: 5.56997
# Epoch [2/3], Step [5500/12942], Loss: 1.9323, Perplexity: 6.90545
# Epoch [2/3], Step [5600/12942], Loss: 1.8857, Perplexity: 6.59072
# Epoch [2/3], Step [5700/12942], Loss: 2.0477, Perplexity: 7.75021
# Epoch [2/3], Step [5800/12942], Loss: 1.6891, Perplexity: 5.41498
# Epoch [2/3], Step [5900/12942], Loss: 2.4215, Perplexity: 11.2631
# Epoch [2/3], Step [6000/12942], Loss: 1.7768, Perplexity: 5.91086
# Epoch [2/3], Step [6100/12942], Loss: 1.7673, Perplexity: 5.85514
# Epoch [2/3], Step [6200/12942], Loss: 2.1444, Perplexity: 8.53665
# Epoch [2/3], Step [6300/12942], Loss: 2.8282, Perplexity: 16.9154
# Epoch [2/3], Step [6400/12942], Loss: 2.1521, Perplexity: 8.60250
# Epoch [2/3], Step [6500/12942], Loss: 1.9093, Perplexity: 6.74849
# Epoch [2/3], Step [6600/12942], Loss: 2.0614, Perplexity: 7.85715
# Epoch [2/3], Step [6700/12942], Loss: 1.7211, Perplexity: 5.59081
# Epoch [2/3], Step [6800/12942], Loss: 2.2114, Perplexity: 9.12873
# Epoch [2/3], Step [6900/12942], Loss: 2.0234, Perplexity: 7.56417
# Epoch [2/3], Step [7000/12942], Loss: 2.4749, Perplexity: 11.8809
# Epoch [2/3], Step [7100/12942], Loss: 2.0335, Perplexity: 7.64111
# Epoch [2/3], Step [7200/12942], Loss: 2.2486, Perplexity: 9.47486
# Epoch [2/3], Step [7300/12942], Loss: 2.0484, Perplexity: 7.75555
# Epoch [2/3], Step [7400/12942], Loss: 1.7820, Perplexity: 5.94205
# Epoch [2/3], Step [7500/12942], Loss: 2.0002, Perplexity: 7.39084
# Epoch [2/3], Step [7600/12942], Loss: 1.9850, Perplexity: 7.27925
# Epoch [2/3], Step [7700/12942], Loss: 1.9735, Perplexity: 7.19598
# Epoch [2/3], Step [7800/12942], Loss: 1.7050, Perplexity: 5.50134
# Epoch [2/3], Step [7900/12942], Loss: 1.8607, Perplexity: 6.42849
# Epoch [2/3], Step [8000/12942], Loss: 1.8580, Perplexity: 6.41100
# Epoch [2/3], Step [8100/12942], Loss: 1.9687, Perplexity: 7.16143
# Epoch [2/3], Step [8200/12942], Loss: 2.6448, Perplexity: 14.0812
# Epoch [2/3], Step [8300/12942], Loss: 1.9807, Perplexity: 7.24755
# Epoch [2/3], Step [8400/12942], Loss: 2.1441, Perplexity: 8.53407
# Epoch [2/3], Step [8500/12942], Loss: 2.1762, Perplexity: 8.81240
# Epoch [2/3], Step [8600/12942], Loss: 1.8377, Perplexity: 6.28232
# Epoch [2/3], Step [8700/12942], Loss: 1.9591, Perplexity: 7.09293
# Epoch [2/3], Step [8800/12942], Loss: 1.5957, Perplexity: 4.93205
# Epoch [2/3], Step [8900/12942], Loss: 1.9506, Perplexity: 7.03272
# Epoch [2/3], Step [9000/12942], Loss: 2.1622, Perplexity: 8.68999
# Epoch [2/3], Step [9100/12942], Loss: 1.8348, Perplexity: 6.26393
# Epoch [2/3], Step [9200/12942], Loss: 1.7839, Perplexity: 5.95326
# Epoch [2/3], Step [9300/12942], Loss: 2.3099, Perplexity: 10.0736
# Epoch [2/3], Step [9400/12942], Loss: 2.4156, Perplexity: 11.1967
# Epoch [2/3], Step [9500/12942], Loss: 1.9235, Perplexity: 6.84494
# Epoch [2/3], Step [9600/12942], Loss: 1.7658, Perplexity: 5.84633
# Epoch [2/3], Step [9700/12942], Loss: 1.9567, Perplexity: 7.07611
# Epoch [2/3], Step [9800/12942], Loss: 1.9712, Perplexity: 7.17936
# Epoch [2/3], Step [9900/12942], Loss: 1.7534, Perplexity: 5.77398
# Epoch [2/3], Step [10000/12942], Loss: 1.8089, Perplexity: 6.1036
# Epoch [2/3], Step [10100/12942], Loss: 1.8565, Perplexity: 6.401088
# Epoch [2/3], Step [10200/12942], Loss: 1.9547, Perplexity: 7.06206
# Epoch [2/3], Step [10300/12942], Loss: 1.8716, Perplexity: 6.49855
# Epoch [2/3], Step [10400/12942], Loss: 2.3059, Perplexity: 10.0330
# Epoch [2/3], Step [10500/12942], Loss: 1.9569, Perplexity: 7.07703
# Epoch [2/3], Step [10600/12942], Loss: 2.1611, Perplexity: 8.68034
# Epoch [2/3], Step [10700/12942], Loss: 1.7530, Perplexity: 5.77208
# Epoch [2/3], Step [10800/12942], Loss: 2.1157, Perplexity: 8.29548
# Epoch [2/3], Step [10900/12942], Loss: 1.9289, Perplexity: 6.88222
# Epoch [2/3], Step [11000/12942], Loss: 2.0123, Perplexity: 7.48051
# Epoch [2/3], Step [11100/12942], Loss: 1.5906, Perplexity: 4.90676
# Epoch [2/3], Step [11200/12942], Loss: 1.8608, Perplexity: 6.42878
# Epoch [2/3], Step [11300/12942], Loss: 1.7671, Perplexity: 5.85411
# Epoch [2/3], Step [11400/12942], Loss: 1.6399, Perplexity: 5.15449
# Epoch [2/3], Step [11500/12942], Loss: 1.9488, Perplexity: 7.02018
# Epoch [2/3], Step [11600/12942], Loss: 1.8847, Perplexity: 6.58440
# Epoch [2/3], Step [11700/12942], Loss: 2.1847, Perplexity: 8.88839
# Epoch [2/3], Step [11800/12942], Loss: 2.1215, Perplexity: 8.34388
# Epoch [2/3], Step [11900/12942], Loss: 1.5904, Perplexity: 4.90552
# Epoch [2/3], Step [12000/12942], Loss: 1.8962, Perplexity: 6.66077
# Epoch [2/3], Step [12100/12942], Loss: 1.7693, Perplexity: 5.86683
# Epoch [2/3], Step [12200/12942], Loss: 1.8128, Perplexity: 6.12752
# Epoch [2/3], Step [12300/12942], Loss: 1.7673, Perplexity: 5.85525
# Epoch [2/3], Step [12400/12942], Loss: 2.1512, Perplexity: 8.59502
# Epoch [2/3], Step [12500/12942], Loss: 3.0366, Perplexity: 20.8352
# Epoch [2/3], Step [12600/12942], Loss: 2.4001, Perplexity: 11.0247
# Epoch [2/3], Step [12700/12942], Loss: 2.0704, Perplexity: 7.92781
# Epoch [2/3], Step [12800/12942], Loss: 2.0707, Perplexity: 7.93057
# Epoch [2/3], Step [12900/12942], Loss: 1.9073, Perplexity: 6.73516
# Epoch [3/3], Step [100/12942], Loss: 1.9565, Perplexity: 7.074577
# Epoch [3/3], Step [200/12942], Loss: 1.9323, Perplexity: 6.90511
# Epoch [3/3], Step [300/12942], Loss: 1.7348, Perplexity: 5.66801
# Epoch [3/3], Step [400/12942], Loss: 2.0282, Perplexity: 7.60029
# Epoch [3/3], Step [500/12942], Loss: 1.8675, Perplexity: 6.47244
# Epoch [3/3], Step [600/12942], Loss: 1.6765, Perplexity: 5.34671
# Epoch [3/3], Step [700/12942], Loss: 2.0153, Perplexity: 7.50324
# Epoch [3/3], Step [800/12942], Loss: 1.5409, Perplexity: 4.66862
# Epoch [3/3], Step [900/12942], Loss: 1.9078, Perplexity: 6.73822
# Epoch [3/3], Step [1000/12942], Loss: 2.0155, Perplexity: 7.5046
# Epoch [3/3], Step [1100/12942], Loss: 1.8062, Perplexity: 6.08703
# Epoch [3/3], Step [1200/12942], Loss: 1.7588, Perplexity: 5.80536
# Epoch [3/3], Step [1300/12942], Loss: 1.9837, Perplexity: 7.26991
# Epoch [3/3], Step [1400/12942], Loss: 1.9840, Perplexity: 7.27177
# Epoch [3/3], Step [1500/12942], Loss: 1.6540, Perplexity: 5.22792
# Epoch [3/3], Step [1600/12942], Loss: 1.7576, Perplexity: 5.79832
# Epoch [3/3], Step [1700/12942], Loss: 2.7239, Perplexity: 15.2400
# Epoch [3/3], Step [1800/12942], Loss: 2.1425, Perplexity: 8.52038
# Epoch [3/3], Step [1900/12942], Loss: 1.8899, Perplexity: 6.61898
# Epoch [3/3], Step [2000/12942], Loss: 2.2386, Perplexity: 9.38058
# Epoch [3/3], Step [2100/12942], Loss: 1.5791, Perplexity: 4.85060
# Epoch [3/3], Step [2200/12942], Loss: 1.9267, Perplexity: 6.86682
# Epoch [3/3], Step [2300/12942], Loss: 1.8899, Perplexity: 6.61895
# Epoch [3/3], Step [2400/12942], Loss: 1.7386, Perplexity: 5.68964
# Epoch [3/3], Step [2500/12942], Loss: 1.5385, Perplexity: 4.65752
# Epoch [3/3], Step [2600/12942], Loss: 2.0381, Perplexity: 7.67625
# Epoch [3/3], Step [2700/12942], Loss: 2.1515, Perplexity: 8.59807
# Epoch [3/3], Step [2800/12942], Loss: 2.1154, Perplexity: 8.29299
# Epoch [3/3], Step [2900/12942], Loss: 1.7073, Perplexity: 5.51387
# Epoch [3/3], Step [3000/12942], Loss: 1.8478, Perplexity: 6.34575
# Epoch [3/3], Step [3100/12942], Loss: 1.8647, Perplexity: 6.45418
# Epoch [3/3], Step [3200/12942], Loss: 1.9553, Perplexity: 7.06646
# Epoch [3/3], Step [3300/12942], Loss: 1.9349, Perplexity: 6.92304
# Epoch [3/3], Step [3400/12942], Loss: 1.6266, Perplexity: 5.08687
# Epoch [3/3], Step [3500/12942], Loss: 1.7526, Perplexity: 5.76970
# Epoch [3/3], Step [3600/12942], Loss: 2.0449, Perplexity: 7.72865
# Epoch [3/3], Step [3700/12942], Loss: 1.9109, Perplexity: 6.75947
# Epoch [3/3], Step [3800/12942], Loss: 1.5120, Perplexity: 4.53585
# Epoch [3/3], Step [3900/12942], Loss: 2.0525, Perplexity: 7.78731
# Epoch [3/3], Step [4000/12942], Loss: 2.4401, Perplexity: 11.4743
# Epoch [3/3], Step [4100/12942], Loss: 1.6968, Perplexity: 5.45666
# Epoch [3/3], Step [4200/12942], Loss: 2.2506, Perplexity: 9.49362
# Epoch [3/3], Step [4300/12942], Loss: 1.8815, Perplexity: 6.56337
# Epoch [3/3], Step [4400/12942], Loss: 1.8066, Perplexity: 6.08957
# Epoch [3/3], Step [4500/12942], Loss: 1.9639, Perplexity: 7.12683
# Epoch [3/3], Step [4600/12942], Loss: 1.7841, Perplexity: 5.95411
# Epoch [3/3], Step [4700/12942], Loss: 1.5982, Perplexity: 4.94438
# Epoch [3/3], Step [4800/12942], Loss: 1.8094, Perplexity: 6.10707
# Epoch [3/3], Step [4900/12942], Loss: 1.7777, Perplexity: 5.91624
# Epoch [3/3], Step [5000/12942], Loss: 1.8258, Perplexity: 6.20759
# Epoch [3/3], Step [5100/12942], Loss: 1.7915, Perplexity: 5.99838
# Epoch [3/3], Step [5200/12942], Loss: 2.0583, Perplexity: 7.83297
# Epoch [3/3], Step [5300/12942], Loss: 1.8176, Perplexity: 6.15691
# Epoch [3/3], Step [5400/12942], Loss: 1.7877, Perplexity: 5.97550
# Epoch [3/3], Step [5500/12942], Loss: 1.5513, Perplexity: 4.71785
# Epoch [3/3], Step [5600/12942], Loss: 1.7545, Perplexity: 5.78066
# Epoch [3/3], Step [5700/12942], Loss: 1.8104, Perplexity: 6.11261
# Epoch [3/3], Step [5800/12942], Loss: 1.7274, Perplexity: 5.62595
# Epoch [3/3], Step [5900/12942], Loss: 1.7359, Perplexity: 5.67403
# Epoch [3/3], Step [6000/12942], Loss: 1.8093, Perplexity: 6.10627
# Epoch [3/3], Step [6100/12942], Loss: 1.7864, Perplexity: 5.96818
# Epoch [3/3], Step [6200/12942], Loss: 2.1663, Perplexity: 8.72596
# Epoch [3/3], Step [6300/12942], Loss: 1.7680, Perplexity: 5.85890
# Epoch [3/3], Step [6400/12942], Loss: 1.9032, Perplexity: 6.70752
# Epoch [3/3], Step [6500/12942], Loss: 2.0452, Perplexity: 7.73114
# Epoch [3/3], Step [6600/12942], Loss: 2.2125, Perplexity: 9.13835
# Epoch [3/3], Step [6700/12942], Loss: 1.9302, Perplexity: 6.89082
# Epoch [3/3], Step [6800/12942], Loss: 1.7846, Perplexity: 5.95750
# Epoch [3/3], Step [6900/12942], Loss: 1.5922, Perplexity: 4.91468
# Epoch [3/3], Step [7000/12942], Loss: 1.9037, Perplexity: 6.71089
# Epoch [3/3], Step [7100/12942], Loss: 1.8989, Perplexity: 6.67854
# Epoch [3/3], Step [7200/12942], Loss: 1.6230, Perplexity: 5.06813
# Epoch [3/3], Step [7300/12942], Loss: 1.8072, Perplexity: 6.09335
# Epoch [3/3], Step [7400/12942], Loss: 1.4853, Perplexity: 4.41622
# Epoch [3/3], Step [7500/12942], Loss: 1.7996, Perplexity: 6.04705
# Epoch [3/3], Step [7600/12942], Loss: 1.7965, Perplexity: 6.02829
# Epoch [3/3], Step [7700/12942], Loss: 1.6844, Perplexity: 5.38907
# Epoch [3/3], Step [7800/12942], Loss: 1.6806, Perplexity: 5.36877
# Epoch [3/3], Step [7900/12942], Loss: 1.7646, Perplexity: 5.83915
# Epoch [3/3], Step [8000/12942], Loss: 1.8822, Perplexity: 6.56778
# Epoch [3/3], Step [8100/12942], Loss: 1.6349, Perplexity: 5.12924
# Epoch [3/3], Step [8200/12942], Loss: 2.0024, Perplexity: 7.40650
# Epoch [3/3], Step [8300/12942], Loss: 1.7075, Perplexity: 5.51500
# Epoch [3/3], Step [8400/12942], Loss: 1.8344, Perplexity: 6.26133
# Epoch [3/3], Step [8500/12942], Loss: 1.8221, Perplexity: 6.18492
# Epoch [3/3], Step [8600/12942], Loss: 2.5224, Perplexity: 12.4589
# Epoch [3/3], Step [8700/12942], Loss: 2.2434, Perplexity: 9.42578
# Epoch [3/3], Step [8800/12942], Loss: 1.6986, Perplexity: 5.46615
# Epoch [3/3], Step [8900/12942], Loss: 1.7227, Perplexity: 5.59956
# Epoch [3/3], Step [9000/12942], Loss: 1.8760, Perplexity: 6.52706
# Epoch [3/3], Step [9100/12942], Loss: 1.7481, Perplexity: 5.74385
# Epoch [3/3], Step [9200/12942], Loss: 2.0290, Perplexity: 7.60699
# Epoch [3/3], Step [9300/12942], Loss: 1.8654, Perplexity: 6.45856
# Epoch [3/3], Step [9400/12942], Loss: 1.9176, Perplexity: 6.80472
# Epoch [3/3], Step [9500/12942], Loss: 2.2279, Perplexity: 9.28018
# Epoch [3/3], Step [9600/12942], Loss: 2.0227, Perplexity: 7.55853
# Epoch [3/3], Step [9700/12942], Loss: 1.5001, Perplexity: 4.48210
# Epoch [3/3], Step [9800/12942], Loss: 1.9855, Perplexity: 7.28314
# Epoch [3/3], Step [9900/12942], Loss: 1.7814, Perplexity: 5.93821
# Epoch [3/3], Step [10000/12942], Loss: 1.6234, Perplexity: 5.0705
# Epoch [3/3], Step [10100/12942], Loss: 1.6816, Perplexity: 5.37428
# Epoch [3/3], Step [10200/12942], Loss: 1.6442, Perplexity: 5.17698
# Epoch [3/3], Step [10300/12942], Loss: 2.0287, Perplexity: 7.60409
# Epoch [3/3], Step [10400/12942], Loss: 2.5011, Perplexity: 12.1962
# Epoch [3/3], Step [10500/12942], Loss: 1.9104, Perplexity: 6.75577
# Epoch [3/3], Step [10600/12942], Loss: 1.6628, Perplexity: 5.27407
# Epoch [3/3], Step [10700/12942], Loss: 1.5698, Perplexity: 4.80569
# Epoch [3/3], Step [10800/12942], Loss: 1.7039, Perplexity: 5.49557
# Epoch [3/3], Step [10900/12942], Loss: 2.1344, Perplexity: 8.45184
# Epoch [3/3], Step [11000/12942], Loss: 2.0906, Perplexity: 8.08952
# Epoch [3/3], Step [11100/12942], Loss: 1.8404, Perplexity: 6.29932
# Epoch [3/3], Step [11200/12942], Loss: 1.8389, Perplexity: 6.28997
# Epoch [3/3], Step [11300/12942], Loss: 1.8866, Perplexity: 6.59685
# Epoch [3/3], Step [11400/12942], Loss: 2.2291, Perplexity: 9.29183
# Epoch [3/3], Step [11500/12942], Loss: 1.7445, Perplexity: 5.72314
# Epoch [3/3], Step [11600/12942], Loss: 1.6808, Perplexity: 5.36985
# Epoch [3/3], Step [11700/12942], Loss: 1.7785, Perplexity: 5.92101
# Epoch [3/3], Step [11800/12942], Loss: 1.8127, Perplexity: 6.12703
# Epoch [3/3], Step [11900/12942], Loss: 1.5061, Perplexity: 4.50934
# Epoch [3/3], Step [12000/12942], Loss: 1.8739, Perplexity: 6.51390
# Epoch [3/3], Step [12100/12942], Loss: 2.1990, Perplexity: 9.01598
# Epoch [3/3], Step [12200/12942], Loss: 1.8722, Perplexity: 6.50247
# Epoch [3/3], Step [12300/12942], Loss: 2.1858, Perplexity: 8.89769
# Epoch [3/3], Step [12400/12942], Loss: 1.8585, Perplexity: 6.41417
# Epoch [3/3], Step [12500/12942], Loss: 1.7379, Perplexity: 5.68531
# Epoch [3/3], Step [12600/12942], Loss: 1.7844, Perplexity: 5.95580
# Epoch [3/3], Step [12700/12942], Loss: 1.6732, Perplexity: 5.32911
# Epoch [3/3], Step [12800/12942], Loss: 1.8818, Perplexity: 6.56547
# Epoch [3/3], Step [12900/12942], Loss: 1.7024, Perplexity: 5.48692
# Epoch [3/3], Step [12942/12942], Loss: 1.9765, Perplexity: 7.21761

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
